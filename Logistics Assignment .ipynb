# %%
import numpy as np
import pandas as pd

# %%
df_OR = pd.read_excel('Company X - Order Report.xlsx')

# %%
df_OR
# Out:
#      ExternOrderNo            SKU  Order Qty
# 0       2001827036  8904223818706        1.0
# 1       2001827036  8904223819093        1.0
# 2       2001827036  8904223819109        1.0
# 3       2001827036  8904223818430        1.0
# 4       2001827036  8904223819277        1.0
# ..             ...            ...        ...
# 395     2001806229  8904223818942        1.0
# 396     2001806229  8904223818850        1.0
# 397     2001806226  8904223818850        2.0
# 398     2001806210  8904223816214        1.0
# 399     2001806210  8904223818874        1.0
#
# [400 rows x 3 columns]

# %%
df_OR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  400 non-null    int64
#  1   SKU            400 non-null    object
#  2   Order Qty      400 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
df_SM = pd.read_excel('Company X - SKU Master.xlsx')

# %%
df_SM
# Out:
#               SKU  Weight (g)
# 0   8904223815682         210
# 1   8904223815859         165
# 2   8904223815866         113
# 3   8904223815873          65
# 4   8904223816214         120
# ..            ...         ...
# 61  8904223819505         210
# 62  8904223819499         210
# 63  8904223819512         210
# 64  8904223819543         300
# 65     SACHETS001          10
#
# [66 rows x 2 columns]

# %%
df_SM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SKU         66 non-null     object
#  1   Weight (g)  66 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df_PZ = pd.read_excel('Company X - Pincode Zones.xlsx')

# %%
df_PZ
# Out:
#      Warehouse Pincode  Customer Pincode Zone
# 0               121003            507101    d
# 1               121003            486886    d
# 2               121003            532484    d
# 3               121003            143001    b
# 4               121003            515591    d
# ..                 ...               ...  ...
# 119             121003            325207    b
# 120             121003            303702    b
# 121             121003            313301    b
# 122             121003            173212    e
# 123             121003            302020    b
#
# [124 rows x 3 columns]

# %%
df_PZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Warehouse Pincode  124 non-null    int64
#  1   Customer Pincode   124 non-null    int64
#  2   Zone               124 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 3.0+ KB

# %%
df_CI = pd.read_excel('Courier Company - Invoice.xlsx')

# %%
df_CI
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
df_CI['Order ID']
# Out:
# 0      2001806232
# 1      2001806273
# 2      2001806408
# 3      2001806458
# 4      2001807012
#           ...
# 119    2001812941
# 120    2001809383
# 121    2001820978
# 122    2001811475
# 123    2001811305
# Name: Order ID, Length: 124, dtype: int64

# %%
df_CI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.9+ KB

# %%
df_CR = pd.read_excel('Courier Company - Rates.xlsx')

# %%
df_CR
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
df_CR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fwd_a_fixed       1 non-null      float64
#  1   fwd_a_additional  1 non-null      float64
#  2   fwd_b_fixed       1 non-null      int64
#  3   fwd_b_additional  1 non-null      float64
#  4   fwd_c_fixed       1 non-null      float64
#  5   fwd_c_additional  1 non-null      float64
#  6   fwd_d_fixed       1 non-null      float64
#  7   fwd_d_additional  1 non-null      float64
#  8   fwd_e_fixed       1 non-null      float64
#  9   fwd_e_additional  1 non-null      float64
#  10  rto_a_fixed       1 non-null      float64
#  11  rto_a_additional  1 non-null      float64
#  12  rto_b_fixed       1 non-null      float64
#  13  rto_b_additional  1 non-null      float64
#  14  rto_c_fixed       1 non-null      float64
#  15  rto_c_additional  1 non-null      float64
# ...

# %%
column_name =  ['Order ID']

# %%
df = pd.DataFrame(columns=column_name)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Order ID]
# Index: []

# %%
df['Order ID'] = df_OR['ExternOrderNo']

# %%
df
# Out:
#        Order ID
# 0    2001827036
# 1    2001827036
# 2    2001827036
# 3    2001827036
# 4    2001827036
# ..          ...
# 395  2001806229
# 396  2001806229
# 397  2001806226
# 398  2001806210
# 399  2001806210
#
# [400 rows x 1 columns]

# %%
merge_data = pd.merge(df_OR,df_SM,on = 'SKU',how = 'left')

# %%
merge_data
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)
# 0       2001827036  8904223818706        1.0         127
# 1       2001827036  8904223819093        1.0         150
# 2       2001827036  8904223819109        1.0         100
# 3       2001827036  8904223818430        1.0         165
# 4       2001827036  8904223819277        1.0         350
# ..             ...            ...        ...         ...
# 396     2001806229  8904223818942        1.0         133
# 397     2001806229  8904223818850        1.0         240
# 398     2001806226  8904223818850        2.0         240
# 399     2001806210  8904223816214        1.0         120
# 400     2001806210  8904223818874        1.0         100
#
# [401 rows x 4 columns]

# %%
merge_data['Total weight as per X (KG)'] = merge_data['Order Qty']*merge_data['Weight (g)']/1000

# %%
merge_data
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  \
# 0       2001827036  8904223818706        1.0         127
# 1       2001827036  8904223819093        1.0         150
# 2       2001827036  8904223819109        1.0         100
# 3       2001827036  8904223818430        1.0         165
# 4       2001827036  8904223819277        1.0         350
# ..             ...            ...        ...         ...
# 396     2001806229  8904223818942        1.0         133
# 397     2001806229  8904223818850        1.0         240
# 398     2001806226  8904223818850        2.0         240
# 399     2001806210  8904223816214        1.0         120
# 400     2001806210  8904223818874        1.0         100
#
#      Total weight as per X (KG)
# 0                         0.127
# 1                         0.150
# 2                         0.100
# 3                         0.165
# 4                         0.350
# ..                          ...
# 396                       0.133
# ...

# %%
columns_drop = ['SKU','Order Qty','Weight (g)']

# %%
c_drop = merge_data.drop(columns_drop,axis = 1)

# %%
c_drop
# Out:
#      ExternOrderNo  Total weight as per X (KG)
# 0       2001827036                       0.127
# 1       2001827036                       0.150
# 2       2001827036                       0.100
# 3       2001827036                       0.165
# 4       2001827036                       0.350
# ..             ...                         ...
# 396     2001806229                       0.133
# 397     2001806229                       0.240
# 398     2001806226                       0.480
# 399     2001806210                       0.120
# 400     2001806210                       0.100
#
# [401 rows x 2 columns]

# %%
group_by = pd.DataFrame(c_drop.groupby(['ExternOrderNo'],as_index = False).sum().round(2))

# %%
group_by
# Out:
#      ExternOrderNo  Total weight as per X (KG)
# 0       2001806210                        0.22
# 1       2001806226                        0.48
# 2       2001806229                        0.50
# 3       2001806232                        1.30
# 4       2001806233                        0.24
# ..             ...                         ...
# 119     2001821995                        0.48
# 120     2001822466                        1.38
# 121     2001823564                        0.67
# 122     2001825261                        1.56
# 123     2001827036                        2.18
#
# [124 rows x 2 columns]

# %%
group_by.rename(columns={'ExternOrderNo':'Order ID'},inplace = True)

# %%
value = lambda x : 0.5 if(x <= 0.5) else (1.0 if (x > 0.5 and x<= 1.0) else (1.5 if(x>1.0 and x <=1.5) else (2.0 if(x >1.5 and x<= 2.0) else (2.5 if(x>2.0 and x<= 2.5)else (3.0 if (x>2.5 and x<=3.0)else (3.5 if(x>3.0 and x <= 3.5)else (4.0 if (x>3.5 and x<=4.0)else x)))))))

# %%
group_by['Weight slab as per X (KG)'] = group_by['Total weight as per X (KG)'].apply(value)

# %%
group_by
# Out:
#        Order ID  Total weight as per X (KG)  Weight slab as per X (KG)
# 0    2001806210                        0.22                        0.5
# 1    2001806226                        0.48                        0.5
# 2    2001806229                        0.50                        0.5
# 3    2001806232                        1.30                        1.5
# 4    2001806233                        0.24                        0.5
# ..          ...                         ...                        ...
# 119  2001821995                        0.48                        0.5
# 120  2001822466                        1.38                        1.5
# 121  2001823564                        0.67                        1.0
# 122  2001825261                        1.56                        2.0
# 123  2001827036                        2.18                        2.5
#
# [124 rows x 3 columns]

# %%
merg_data = pd.merge(group_by,df_CI,on = 'Order ID',how = 'left')

# %%
merg_data
# Out:
#        Order ID  Total weight as per X (KG)  Weight slab as per X (KG)  \
# 0    2001806210                        0.22                        0.5
# 1    2001806226                        0.48                        0.5
# 2    2001806229                        0.50                        0.5
# 3    2001806232                        1.30                        1.5
# 4    2001806233                        0.24                        0.5
# ..          ...                         ...                        ...
# 119  2001821995                        0.48                        0.5
# 120  2001822466                        1.38                        1.5
# 121  2001823564                        0.67                        1.0
# 122  2001825261                        1.56                        2.0
# 123  2001827036                        2.18                        2.5
#
#           AWB Code  Charged Weight  Warehouse Pincode  Customer Pincode Zone  \
# ...

# %%
columns = merg_data.columns.tolist()

# %%
columns.insert(1,columns.pop(3))

# %%
arrange = merg_data[columns]

# %%
arrange
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Charged Weight  Warehouse Pincode  \
# 0                          0.5            2.92             121003
# 1                          0.5            0.68             121003
# ...

# %%
arrange.rename(columns={'Charged Weight':'Total weight as per Courier Company (KG)','Zone':'Delivery Zone charged by Courier Company','Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.) '},inplace = True)

# %%
arrange
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
arrange.insert(5,'Weight slab charged by Courier Company (KG)',arrange['Total weight as per Courier Company (KG)'].apply(value))

# %%
arrange
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
com = pd.merge(arrange,df_PZ,on = 'Customer Pincode',how = 'left')

# %%
com
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 169  2001821995  1091121183730                        0.48
# 170  2001822466  1091121305541                        1.38
# 171  2001823564  1091121666133                        0.67
# 172  2001825261  1091121981575                        1.56
# 173  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
dup = com.drop_duplicates(subset='Order ID')

# %%
d = dup.reset_index(drop=True)

# %%
d
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
columns_d = ['Warehouse Pincode_x','Customer Pincode','Warehouse Pincode_y']

# %%
_drop = d.drop(columns_d,axis = 1)

# %%
_drop
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
columns = _drop.columns.tolist()

# %%
columns.insert(6,columns.pop(9))

# %%
_drop = _drop[columns]

# %%
_drop
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
_drop.rename(columns={'Zone':'Delivery Zone as per X'},inplace = True)

# %%
_drop
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
def calculate_value (row):
    
     if row['Type of Shipment'] == 'Forward charges' and row['Delivery Zone as per X'] == 'a':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*23.6+29.5
        return result
     elif row['Type of Shipment'] == 'Forward charges' and row['Delivery Zone as per X'] == 'b':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*28.3+33
        return result 
     elif row['Type of Shipment'] == 'Forward charges' and row['Delivery Zone as per X'] == 'c':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*38.9+40.1
        return result 
     elif row['Type of Shipment'] == 'Forward charges' and row['Delivery Zone as per X'] == 'd':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*44.8+45.4
        return result 
     elif row['Type of Shipment'] == 'Forward charges' and row['Delivery Zone as per X'] == 'e':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*55.5+56.6
        return result 
     elif row['Type of Shipment'] == 'Forward and RTO charges' and row['Delivery Zone as per X'] == 'a':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*(23.6*2)+29.5+13.6
        return result
     elif row['Type of Shipment'] == 'Forward and RTO charges' and row['Delivery Zone as per X'] == 'b':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*(28.3*2)+33+20.5
        return result
     elif row['Type of Shipment'] == 'Forward and RTO charges' and row['Delivery Zone as per X'] == 'c':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*(38.9*2)+40.1+31.9
        return result 
     elif row['Type of Shipment'] == 'Forward and RTO charges' and row['Delivery Zone as per X'] == 'd':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*(44.8*2)+45.4+41.3
        return result 
     elif row['Type of Shipment'] == 'Forward and RTO charges' and row['Delivery Zone as per X'] == 'e':
        result = (row['Weight slab as per X (KG)']-0.5)/0.5*(55.5*2)+56.6+50.7
        return result 
     else:
        return None

# %%
_drop.insert(9,'Expected Charge as per X (Rs.)', _drop.apply(lambda row : calculate_value (row),axis=1))

# %%
_drop
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
df = _drop.drop('Type of Shipment',axis = 1)

# %%
df
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
df['Difference Between Expected Charges and Billed Charges (Rs.)'] = df['Expected Charge as per X (Rs.)'] - df['Charges Billed by Courier Company (Rs.) ']

# %%
df
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
writer = pd.ExcelWriter("Logistics Assignment calculation.xlsx")

# %%
df.to_excel(writer,sheet_name="Logistic Assignment Analysis")

# %%
writer._save()

# %%
d =  {" " : ['Total orders where X has been correctly charged']}

# %%
df1 = pd.DataFrame(data=d)

# %%
df1
# Out:
#
# 0  Total orders where X has been correctly charged

# %%
df1['Count'] = (df['Difference Between Expected Charges and Billed Charges (Rs.)']==0).sum()

# %%
df1
# Out:
#                                                     Count
# 0  Total orders where X has been correctly charged     17

# %%
df1['Amount (Rs.)'] = df['Expected Charge as per X (Rs.)'].sum()

# %%
df1
# Out:
#                                                     Count  Amount (Rs.)
# 0  Total orders where X has been correctly charged     17        9795.6

# %%
df['over'] = np.where(df['Difference Between Expected Charges and Billed Charges (Rs.)'] <0,df['Difference Between Expected Charges and Billed Charges (Rs.)'],0)

# %%
df
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
df['under'] = np.where(df['Difference Between Expected Charges and Billed Charges (Rs.)'] >0,df['Difference Between Expected Charges and Billed Charges (Rs.)'],0)

# %%
df
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
a =  {" " : ['Total Orders where X has been overcharged']}

# %%
df2 = pd.DataFrame(data=a)

# %%
df2
# Out:
#
# 0  Total Orders where X has been overcharged

# %%
df2['Count'] = (df['Difference Between Expected Charges and Billed Charges (Rs.)']<0).sum()

# %%
df2
# Out:
#                                               Count
# 0  Total Orders where X has been overcharged     84

# %%
df2['Amount (Rs.)'] = df['over'].sum()

# %%
df2
# Out:
#                                               Count  Amount (Rs.)
# 0  Total Orders where X has been overcharged     84       -4454.9

# %%
b =  {" " : ['Total Orders where X has been undercharged']}

# %%
df3 = pd.DataFrame(data=b)

# %%
df3
# Out:
#
# 0  Total Orders where X has been undercharged

# %%
df3['Count'] = (df['Difference Between Expected Charges and Billed Charges (Rs.)']>0).sum()

# %%
df3
# Out:
#                                                Count
# 0  Total Orders where X has been undercharged     23

# %%
df3['Amount (Rs.)'] = df['under'].sum()

# %%
df3
# Out:
#                                                Count  Amount (Rs.)
# 0  Total Orders where X has been undercharged     23         602.3

# %%
df4 = pd.concat([df1,df2,df3],ignore_index = True)

# %%
df4
# Out:
#                                                     Count  Amount (Rs.)
# 0  Total orders where X has been correctly charged     17        9795.6
# 1        Total Orders where X has been overcharged     84       -4454.9
# 2       Total Orders where X has been undercharged     23         602.3

# %%
dff = df.drop(['over','under'],axis = 1)

# %%
dff
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806210  1091117221940                        0.22
# 1    2001806226  1091117222065                        0.48
# 2    2001806229  1091117222080                        0.50
# 3    2001806232  1091117222124                        1.30
# 4    2001806233  1091117222135                        0.24
# ..          ...            ...                         ...
# 119  2001821995  1091121183730                        0.48
# 120  2001822466  1091121305541                        1.38
# 121  2001823564  1091121666133                        0.67
# 122  2001825261  1091121981575                        1.56
# 123  2001827036  1091122418320                        2.18
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          0.5                                      2.92
# 1                          0.5                                      0.68
# ...

# %%
writer = pd.ExcelWriter("summary table.xlsx")

# %%
df4.to_excel(writer,sheet_name="summary")

# %%
writer._save()
